# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import minimize
from dateutil.relativedelta import relativedelta

# %%
ER = pd.read_excel('all_data/Bayes_stein_returns.xlsx')
garch_vol = pd.read_excel('all_data/garch_volatility_forecasts.xlsx')
hist_vol = pd.read_excel('all_data/realized_volatility.xlsx')

# Convert Date columns to datetime
ER['Date'] = pd.to_datetime(ER['Date'])
garch_vol['Date'] = pd.to_datetime(garch_vol['Date'])

# %%
# Optimization function
def mvo_optimize(expected_returns, covariance_matrix, bounds, init_guess, risk_aversion=5):
    def objective(weights):
        portfolio_return = np.dot(weights, expected_returns)
        portfolio_variance = np.dot(weights.T, np.dot(covariance_matrix, weights))
        utility = portfolio_return - (risk_aversion/2) * portfolio_variance
        return -utility
    
    constraints = {'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1}
    
    result = minimize(
        objective,
        init_guess,
        method='SLSQP',
        bounds=bounds,
        constraints=constraints,
        options={'ftol': 1e-9}
    )
    
    if not result.success:
        print(f"Warning: Optimization failed - {result.message}")
        return None
    
    return result.x

# Bounds function
def volatility_based_bounds(volatilities, min_bound=0.001, max_bound=0.20, range_width=0.10):
    inv_vol = 1 / volatilities
    weights = inv_vol / inv_vol.sum()
    
    bounds = []
    for w in weights:
        lower = max(min_bound, w - range_width / 2)
        upper = min(max_bound, w + range_width / 2)
        bounds.append((lower, upper))
    return bounds

# %%
# Check ER structure
print("ER DATA:")
print(ER.head())
print(f"Shape: {ER.shape}")
print(f"Date range: {ER['Date'].min()} to {ER['Date'].max()}")
print(f"Columns: {ER.columns.tolist()}")

print("\n" + "="*50 + "\n")

# Check garch_vol structure
print("GARCH_VOL DATA:")
print(hist_vol.head())
print(f"Shape: {hist_vol.shape}")
print(f"Date range: {hist_vol['Date'].min()} to {hist_vol['Date'].max()}")
print(f"Columns: {hist_vol.columns.tolist()}")
# Out:
# ER DATA:
#         Date      AAPL       ABT       AMD      AMZN      AVGO       AXP  \
# 0 2012-01-03  0.000127  0.001078 -0.001161 -0.004720 -0.003342 -0.001480
# 1 2012-01-04  0.000980  0.001777  0.001357 -0.003747 -0.002725 -0.000097
# 2 2012-01-05  0.001054  0.001630  0.000551 -0.004344 -0.002848 -0.000729
# 3 2012-01-06  0.000979  0.001143 -0.000626 -0.004626 -0.004078 -0.001096
# 4 2012-01-09  0.001395  0.001153 -0.000508 -0.003758 -0.004263 -0.001124
#
#         BAC     BRK-B       CAT  ...        PM      QCOM       RTX       TMO  \
# 0 -0.004291 -0.000344 -0.000678  ...  0.003079  0.001708 -0.001222 -0.002482
# 1 -0.001765  0.000802  0.000924  ...  0.003491  0.002630  0.000141 -0.000674
# 2 -0.002914 -0.000088  0.000544  ...  0.003064  0.001902 -0.000279 -0.001715
# 3 -0.001538 -0.000457  0.000190  ...  0.002677  0.000207 -0.000981 -0.001752
# 4 -0.000582 -0.000147  0.000314  ...  0.002528  0.000084 -0.000925 -0.000435
#
#        TMUS       UNH         V       WFC       WMT       XOM
# 0  0.001296  0.001532  0.002230  0.001901  0.001446  0.002213
# 1  0.005597  0.002791  0.003397  0.003700  0.001878  0.003217
# 2  0.001247  0.003066  0.002583  0.003152  0.001367  0.002774
# 3 -0.002033  0.003318  0.002325  0.003084  0.001017  0.002244
# 4 -0.001950  0.003713  0.002183  0.003397  0.000815  0.002169
#
# [5 rows x 46 columns]
# Shape: (3455, 46)
# Date range: 2012-01-03 00:00:00 to 2025-09-29 00:00:00
# Columns: ['Date', 'AAPL', 'ABT', 'AMD', 'AMZN', 'AVGO', 'AXP', 'BAC', 'BRK-B', 'CAT', 'COST', 'CRM', 'CSCO', 'CVX', 'DIS', 'GE', 'GOOG', 'GOOGL', 'GS', 'HD', 'IBM', 'JNJ', 'JPM', 'KO', 'LLY', 'LRCX', 'MA', 'MCD', 'MRK', 'MS', 'MSFT', 'MU', 'NFLX', 'NVDA', 'ORCL', 'PG', 'PM', 'QCOM', 'RTX', 'TMO', 'TMUS', 'UNH', 'V', 'WFC', 'WMT', 'XOM']
#
# ==================================================
#
# GARCH_VOL DATA:
#         Date      AAPL       ABT       AMD      AMZN      AVGO       AXP  \
# 0 2012-01-03  0.015266  0.008677  0.014706  0.033684  0.003113  0.025535
# 1 2012-01-04  0.005360  0.003887  0.003656  0.008526  0.017422  0.000622
# 2 2012-01-05  0.011041  0.002303  0.000000  0.000563  0.001404  0.011542
# 3 2012-01-06  0.010400  0.009088  0.005510  0.027763  0.006338  0.010920
# 4 2012-01-09  0.001588  0.000179  0.029040  0.022428  0.065289  0.002483
#
#         BAC     BRK-B       CAT  ...        PM      QCOM       RTX       TMO  \
# 0  0.042259  0.017925  0.036628  ...  0.001400  0.010367  0.021253  0.042022
# 1  0.001723  0.011393  0.009214  ...  0.001783  0.010081  0.005210  0.020464
# 2  0.082555  0.001691  0.007039  ...  0.003065  0.004111  0.009640  0.008452
# 3  0.020817  0.007044  0.002510  ...  0.014553  0.001783  0.005802  0.027248
# 4  0.014458  0.001310  0.013896  ...  0.002858  0.004462  0.002703  0.001049
#
#        TMUS       UNH         V       WFC       WMT       XOM
# 0  0.078624  0.015856  0.014277  0.031079  0.009493  0.014524
# 1  0.066031  0.014461  0.018028  0.004562  0.010330  0.000233
# 2  0.092924  0.006677  0.007486  0.015978  0.004868  0.003027
# 3  0.001248  0.003607  0.011845  0.002761  0.007094  0.007491
# 4  0.022195  0.001138  0.008075  0.012363  0.003046  0.004455
#
# [5 rows x 46 columns]
# Shape: (3455, 46)
# Date range: 2012-01-03 00:00:00 to 2025-09-29 00:00:00
# Columns: ['Date', 'AAPL', 'ABT', 'AMD', 'AMZN', 'AVGO', 'AXP', 'BAC', 'BRK-B', 'CAT', 'COST', 'CRM', 'CSCO', 'CVX', 'DIS', 'GE', 'GOOG', 'GOOGL', 'GS', 'HD', 'IBM', 'JNJ', 'JPM', 'KO', 'LLY', 'LRCX', 'MA', 'MCD', 'MRK', 'MS', 'MSFT', 'MU', 'NFLX', 'NVDA', 'ORCL', 'PG', 'PM', 'QCOM', 'RTX', 'TMO', 'TMUS', 'UNH', 'V', 'WFC', 'WMT', 'XOM']

# %%
# Get date range
start_date = pd.to_datetime('2012-01-01')
end_date = ER['Date'].max()

# Storage for results
results_hist = []

current_start = start_date

while current_start <= end_date - relativedelta(months=2):
    # Define the 2-month estimation window end
    estimation_window_end = current_start + relativedelta(months=2)
    
    # Define target month start (month after estimation window)
    target_month_start = estimation_window_end
    
    # Get returns for EXACTLY 2-month estimation period
    returns_window = ER[(ER['Date'] >= current_start) & (ER['Date'] < estimation_window_end)].drop('Date', axis=1)
    
    # Skip if insufficient data
    if len(returns_window) < 20:
        current_start += relativedelta(months=1)
        continue
    
    # Calculate correlation matrix and expected returns from 2-month window
    R = returns_window.corr().values
    expected_returns = returns_window.mean().values
    
    # Get historical volatilities from 2-month window
    vol_hist = returns_window.std().values
    
    # Build covariance matrix
    D_hist = np.diag(vol_hist)
    Sigma_hist = D_hist @ R @ D_hist
    
    # Setup bounds and initial guess
    bounds = volatility_based_bounds(vol_hist)
    init_guess = (1 / vol_hist) / (1 / vol_hist).sum()
    
    # Optimize portfolio
    weights_hist = mvo_optimize(expected_returns, Sigma_hist, bounds, init_guess)
    
    # Store results if optimization succeeded
    if weights_hist is not None:
        stock_names = returns_window.columns.tolist()
        
        # Store historical weights
        result_hist = {'Date': target_month_start}
        for name, weight in zip(stock_names, weights_hist):
            result_hist[name] = weight
        results_hist.append(result_hist)
        
        # For display
        last_estimation_date = ER[ER['Date'] < estimation_window_end]['Date'].max()
        print(f"Estimation: {current_start.strftime('%Y-%m-%d')} to {last_estimation_date.strftime('%Y-%m-%d')} ({len(returns_window)} days) → Weights for {target_month_start.strftime('%Y-%m')}")
    
    # Move to next month
    current_start += relativedelta(months=1)

# Convert results to DataFrame
weights_hist_df = pd.DataFrame(results_hist)
# Out:
# Estimation: 2012-01-01 to 2012-02-29 (40 days) → Weights for 2012-03
# Estimation: 2012-02-01 to 2012-03-30 (42 days) → Weights for 2012-04
# Estimation: 2012-03-01 to 2012-04-30 (42 days) → Weights for 2012-05
# Estimation: 2012-04-01 to 2012-05-31 (42 days) → Weights for 2012-06
# Estimation: 2012-05-01 to 2012-06-29 (43 days) → Weights for 2012-07
# Estimation: 2012-06-01 to 2012-07-31 (42 days) → Weights for 2012-08
# Estimation: 2012-07-01 to 2012-08-31 (44 days) → Weights for 2012-09
# Estimation: 2012-08-01 to 2012-09-28 (42 days) → Weights for 2012-10
# Estimation: 2012-09-01 to 2012-10-31 (40 days) → Weights for 2012-11
# Estimation: 2012-10-01 to 2012-11-30 (42 days) → Weights for 2012-12
# Estimation: 2012-11-01 to 2012-12-31 (41 days) → Weights for 2013-01
# Estimation: 2012-12-01 to 2013-01-31 (41 days) → Weights for 2013-02
# Estimation: 2013-01-01 to 2013-02-28 (40 days) → Weights for 2013-03
# Estimation: 2013-02-01 to 2013-03-28 (39 days) → Weights for 2013-04
# Estimation: 2013-03-01 to 2013-04-30 (42 days) → Weights for 2013-05
# Estimation: 2013-04-01 to 2013-05-31 (44 days) → Weights for 2013-06
# Estimation: 2013-05-01 to 2013-06-28 (42 days) → Weights for 2013-07
# Estimation: 2013-06-01 to 2013-07-31 (42 days) → Weights for 2013-08
# Estimation: 2013-07-01 to 2013-08-30 (44 days) → Weights for 2013-09
# Estimation: 2013-08-01 to 2013-09-30 (42 days) → Weights for 2013-10
# Estimation: 2013-09-01 to 2013-10-31 (43 days) → Weights for 2013-11
# Estimation: 2013-10-01 to 2013-11-29 (43 days) → Weights for 2013-12
# Estimation: 2013-11-01 to 2013-12-31 (41 days) → Weights for 2014-01
# Estimation: 2013-12-01 to 2014-01-31 (42 days) → Weights for 2014-02
# Estimation: 2014-01-01 to 2014-02-28 (40 days) → Weights for 2014-03
# Estimation: 2014-02-01 to 2014-03-31 (40 days) → Weights for 2014-04
# Estimation: 2014-03-01 to 2014-04-30 (42 days) → Weights for 2014-05
# Estimation: 2014-04-01 to 2014-05-30 (42 days) → Weights for 2014-06
# Estimation: 2014-05-01 to 2014-06-30 (42 days) → Weights for 2014-07
# Estimation: 2014-06-01 to 2014-07-31 (43 days) → Weights for 2014-08
# Estimation: 2014-07-01 to 2014-08-29 (43 days) → Weights for 2014-09
# Estimation: 2014-08-01 to 2014-09-30 (42 days) → Weights for 2014-10
# Estimation: 2014-09-01 to 2014-10-31 (44 days) → Weights for 2014-11
# Estimation: 2014-10-01 to 2014-11-28 (42 days) → Weights for 2014-12
# Estimation: 2014-11-01 to 2014-12-31 (41 days) → Weights for 2015-01
# Estimation: 2014-12-01 to 2015-01-30 (42 days) → Weights for 2015-02
# Estimation: 2015-01-01 to 2015-02-27 (39 days) → Weights for 2015-03
# Estimation: 2015-02-01 to 2015-03-31 (41 days) → Weights for 2015-04
# Estimation: 2015-03-01 to 2015-04-30 (43 days) → Weights for 2015-05
# Estimation: 2015-04-01 to 2015-05-29 (41 days) → Weights for 2015-06
# Estimation: 2015-05-01 to 2015-06-30 (42 days) → Weights for 2015-07
# Estimation: 2015-06-01 to 2015-07-31 (44 days) → Weights for 2015-08
# Estimation: 2015-07-01 to 2015-08-31 (43 days) → Weights for 2015-09
# Estimation: 2015-08-01 to 2015-09-30 (42 days) → Weights for 2015-10
# Estimation: 2015-09-01 to 2015-10-30 (43 days) → Weights for 2015-11
# Estimation: 2015-10-01 to 2015-11-30 (42 days) → Weights for 2015-12
# Estimation: 2015-11-01 to 2015-12-31 (42 days) → Weights for 2016-01
# Estimation: 2015-12-01 to 2016-01-29 (41 days) → Weights for 2016-02
# Estimation: 2016-01-01 to 2016-02-29 (39 days) → Weights for 2016-03
# Estimation: 2016-02-01 to 2016-03-31 (42 days) → Weights for 2016-04
# Estimation: 2016-03-01 to 2016-04-29 (43 days) → Weights for 2016-05
# Estimation: 2016-04-01 to 2016-05-31 (42 days) → Weights for 2016-06
# Estimation: 2016-05-01 to 2016-06-30 (43 days) → Weights for 2016-07
# Estimation: 2016-06-01 to 2016-07-29 (42 days) → Weights for 2016-08
# Estimation: 2016-07-01 to 2016-08-31 (43 days) → Weights for 2016-09
# Estimation: 2016-08-01 to 2016-09-30 (44 days) → Weights for 2016-10
# Estimation: 2016-09-01 to 2016-10-31 (42 days) → Weights for 2016-11
# Estimation: 2016-10-01 to 2016-11-30 (42 days) → Weights for 2016-12
# Estimation: 2016-11-01 to 2016-12-30 (42 days) → Weights for 2017-01
# Estimation: 2016-12-01 to 2017-01-31 (41 days) → Weights for 2017-02
# Estimation: 2017-01-01 to 2017-02-28 (39 days) → Weights for 2017-03
# Estimation: 2017-02-01 to 2017-03-31 (42 days) → Weights for 2017-04
# Estimation: 2017-03-01 to 2017-04-28 (42 days) → Weights for 2017-05
# Estimation: 2017-04-01 to 2017-05-31 (41 days) → Weights for 2017-06
# Estimation: 2017-05-01 to 2017-06-30 (44 days) → Weights for 2017-07
# Estimation: 2017-06-01 to 2017-07-31 (42 days) → Weights for 2017-08
# Estimation: 2017-07-01 to 2017-08-31 (43 days) → Weights for 2017-09
# Estimation: 2017-08-01 to 2017-09-29 (43 days) → Weights for 2017-10
# Estimation: 2017-09-01 to 2017-10-31 (42 days) → Weights for 2017-11
# Estimation: 2017-10-01 to 2017-11-30 (43 days) → Weights for 2017-12
# Estimation: 2017-11-01 to 2017-12-29 (41 days) → Weights for 2018-01
# Estimation: 2017-12-01 to 2018-01-31 (41 days) → Weights for 2018-02
# Estimation: 2018-01-01 to 2018-02-28 (40 days) → Weights for 2018-03
# Estimation: 2018-02-01 to 2018-03-29 (40 days) → Weights for 2018-04
# Estimation: 2018-03-01 to 2018-04-30 (42 days) → Weights for 2018-05
# Estimation: 2018-04-01 to 2018-05-31 (43 days) → Weights for 2018-06
# Estimation: 2018-05-01 to 2018-06-29 (43 days) → Weights for 2018-07
# Estimation: 2018-06-01 to 2018-07-31 (42 days) → Weights for 2018-08
# Estimation: 2018-07-01 to 2018-08-31 (44 days) → Weights for 2018-09
# Estimation: 2018-08-01 to 2018-09-28 (42 days) → Weights for 2018-10
# Estimation: 2018-09-01 to 2018-10-31 (42 days) → Weights for 2018-11
# Estimation: 2018-10-01 to 2018-11-30 (44 days) → Weights for 2018-12
# Estimation: 2018-11-01 to 2018-12-31 (40 days) → Weights for 2019-01
# Estimation: 2018-12-01 to 2019-01-31 (40 days) → Weights for 2019-02
# Estimation: 2019-01-01 to 2019-02-28 (40 days) → Weights for 2019-03
# Estimation: 2019-02-01 to 2019-03-29 (40 days) → Weights for 2019-04
# Estimation: 2019-03-01 to 2019-04-30 (42 days) → Weights for 2019-05
# Estimation: 2019-04-01 to 2019-05-31 (43 days) → Weights for 2019-06
# Estimation: 2019-05-01 to 2019-06-28 (42 days) → Weights for 2019-07
# Estimation: 2019-06-01 to 2019-07-31 (42 days) → Weights for 2019-08
# Estimation: 2019-07-01 to 2019-08-30 (44 days) → Weights for 2019-09
# Estimation: 2019-08-01 to 2019-09-30 (42 days) → Weights for 2019-10
# Estimation: 2019-09-01 to 2019-10-31 (43 days) → Weights for 2019-11
# Estimation: 2019-10-01 to 2019-11-29 (43 days) → Weights for 2019-12
# Estimation: 2019-11-01 to 2019-12-31 (41 days) → Weights for 2020-01
# Estimation: 2019-12-01 to 2020-01-31 (42 days) → Weights for 2020-02
# Estimation: 2020-01-01 to 2020-02-28 (40 days) → Weights for 2020-03
# Estimation: 2020-02-01 to 2020-03-31 (41 days) → Weights for 2020-04
# Estimation: 2020-03-01 to 2020-04-30 (43 days) → Weights for 2020-05
# Estimation: 2020-04-01 to 2020-05-29 (41 days) → Weights for 2020-06
# Estimation: 2020-05-01 to 2020-06-30 (42 days) → Weights for 2020-07
# Estimation: 2020-06-01 to 2020-07-31 (44 days) → Weights for 2020-08
# Estimation: 2020-07-01 to 2020-08-31 (43 days) → Weights for 2020-09
# Estimation: 2020-08-01 to 2020-09-30 (42 days) → Weights for 2020-10
# Estimation: 2020-09-01 to 2020-10-30 (43 days) → Weights for 2020-11
# Estimation: 2020-10-01 to 2020-11-30 (42 days) → Weights for 2020-12
# Estimation: 2020-11-01 to 2020-12-31 (42 days) → Weights for 2021-01
# Estimation: 2020-12-01 to 2021-01-29 (41 days) → Weights for 2021-02
# Estimation: 2021-01-01 to 2021-02-26 (38 days) → Weights for 2021-03
# Estimation: 2021-02-01 to 2021-03-31 (42 days) → Weights for 2021-04
# Estimation: 2021-03-01 to 2021-04-30 (44 days) → Weights for 2021-05
# Estimation: 2021-04-01 to 2021-05-28 (41 days) → Weights for 2021-06
# Estimation: 2021-05-01 to 2021-06-30 (42 days) → Weights for 2021-07
# Estimation: 2021-06-01 to 2021-07-30 (43 days) → Weights for 2021-08
# Estimation: 2021-07-01 to 2021-08-31 (43 days) → Weights for 2021-09
# Estimation: 2021-08-01 to 2021-09-30 (43 days) → Weights for 2021-10
# Estimation: 2021-09-01 to 2021-10-29 (42 days) → Weights for 2021-11
# Estimation: 2021-10-01 to 2021-11-30 (42 days) → Weights for 2021-12
# Estimation: 2021-11-01 to 2021-12-31 (43 days) → Weights for 2022-01
# Estimation: 2021-12-01 to 2022-01-31 (42 days) → Weights for 2022-02
# Estimation: 2022-01-01 to 2022-02-28 (39 days) → Weights for 2022-03
# Estimation: 2022-02-01 to 2022-03-31 (42 days) → Weights for 2022-04
# Estimation: 2022-03-01 to 2022-04-29 (43 days) → Weights for 2022-05
# Estimation: 2022-04-01 to 2022-05-31 (41 days) → Weights for 2022-06
# Estimation: 2022-05-01 to 2022-06-30 (42 days) → Weights for 2022-07
# Estimation: 2022-06-01 to 2022-07-29 (41 days) → Weights for 2022-08
# Estimation: 2022-07-01 to 2022-08-31 (43 days) → Weights for 2022-09
# Estimation: 2022-08-01 to 2022-09-30 (44 days) → Weights for 2022-10
# Estimation: 2022-09-01 to 2022-10-31 (42 days) → Weights for 2022-11
# Estimation: 2022-10-01 to 2022-11-30 (42 days) → Weights for 2022-12
# Estimation: 2022-11-01 to 2022-12-30 (42 days) → Weights for 2023-01
# Estimation: 2022-12-01 to 2023-01-31 (41 days) → Weights for 2023-02
# Estimation: 2023-01-01 to 2023-02-28 (39 days) → Weights for 2023-03
# Estimation: 2023-02-01 to 2023-03-31 (42 days) → Weights for 2023-04
# Estimation: 2023-03-01 to 2023-04-28 (42 days) → Weights for 2023-05
# Estimation: 2023-04-01 to 2023-05-31 (41 days) → Weights for 2023-06
# Estimation: 2023-05-01 to 2023-06-30 (43 days) → Weights for 2023-07
# Estimation: 2023-06-01 to 2023-07-31 (41 days) → Weights for 2023-08
# Estimation: 2023-07-01 to 2023-08-31 (43 days) → Weights for 2023-09
# Estimation: 2023-08-01 to 2023-09-29 (43 days) → Weights for 2023-10
# Estimation: 2023-09-01 to 2023-10-31 (42 days) → Weights for 2023-11
# Estimation: 2023-10-01 to 2023-11-30 (43 days) → Weights for 2023-12
# Estimation: 2023-11-01 to 2023-12-29 (41 days) → Weights for 2024-01
# Estimation: 2023-12-01 to 2024-01-31 (41 days) → Weights for 2024-02
# Estimation: 2024-01-01 to 2024-02-29 (41 days) → Weights for 2024-03
# Estimation: 2024-02-01 to 2024-03-28 (40 days) → Weights for 2024-04
# Estimation: 2024-03-01 to 2024-04-30 (42 days) → Weights for 2024-05
# Estimation: 2024-04-01 to 2024-05-31 (44 days) → Weights for 2024-06
# Estimation: 2024-05-01 to 2024-06-28 (41 days) → Weights for 2024-07
# Estimation: 2024-06-01 to 2024-07-31 (41 days) → Weights for 2024-08
# Estimation: 2024-07-01 to 2024-08-30 (44 days) → Weights for 2024-09
# Estimation: 2024-08-01 to 2024-09-30 (42 days) → Weights for 2024-10
# Estimation: 2024-09-01 to 2024-10-31 (43 days) → Weights for 2024-11
# Estimation: 2024-10-01 to 2024-11-29 (43 days) → Weights for 2024-12
# Estimation: 2024-11-01 to 2024-12-31 (41 days) → Weights for 2025-01
# Estimation: 2024-12-01 to 2025-01-31 (41 days) → Weights for 2025-02
# Estimation: 2025-01-01 to 2025-02-28 (39 days) → Weights for 2025-03
# Estimation: 2025-02-01 to 2025-03-31 (40 days) → Weights for 2025-04
# Estimation: 2025-03-01 to 2025-04-30 (42 days) → Weights for 2025-05
# Estimation: 2025-04-01 to 2025-05-30 (42 days) → Weights for 2025-06
# Estimation: 2025-05-01 to 2025-06-30 (41 days) → Weights for 2025-07
# Estimation: 2025-06-01 to 2025-07-31 (42 days) → Weights for 2025-08
# Estimation: 2025-07-01 to 2025-08-29 (43 days) → Weights for 2025-09

# %%
weights_hist_df.head()
# Out:
#         Date      AAPL       ABT       AMD      AMZN      AVGO       AXP  \
# 0 2012-03-01  0.061585  0.011602  0.057022  0.001000  0.001000  0.001000
# 1 2012-04-01  0.064934  0.001000  0.062246  0.001000  0.065915  0.001000
# 2 2012-05-01  0.060354  0.001000  0.056814  0.001000  0.058504  0.081324
# 3 2012-06-01  0.057726  0.084618  0.001000  0.061781  0.001000  0.066398
# 4 2012-07-01  0.001000  0.080306  0.001000  0.063855  0.001000  0.063378
#
#         BAC     BRK-B       CAT  ...        PM      QCOM    RTX       TMO  \
# 0  0.055492  0.001000  0.061573  ...  0.001000  0.001000  0.001  0.037028
# 1  0.061963  0.013300  0.058687  ...  0.001000  0.001000  0.001  0.064505
# 2  0.056513  0.001831  0.001000  ...  0.070525  0.039153  0.001  0.001000
# 3  0.001000  0.001000  0.001000  ...  0.067551  0.001000  0.001  0.001000
# 4  0.001000  0.088129  0.001000  ...  0.001000  0.001000  0.001  0.001000
#
#        TMUS       UNH         V       WFC       WMT    XOM
# 0  0.058460  0.001000  0.001000  0.075279  0.001000  0.001
# 1  0.060071  0.001000  0.069006  0.001000  0.001000  0.001
# 2  0.001000  0.001000  0.066027  0.075218  0.001000  0.001
# 3  0.001000  0.071311  0.072108  0.063938  0.001000  0.001
# 4  0.001000  0.083829  0.066851  0.001000  0.066097  0.001
#
# [5 rows x 46 columns]

# %%
print(f"\nTotal portfolios created: {len(weights_hist_df)}")
print(f"Date range: {weights_hist_df['Date'].min()} to {weights_hist_df['Date'].max()}")
# Out:
# Total portfolios created: 163
# Date range: 2012-03-01 00:00:00 to 2025-09-01 00:00:00

# %%
weights_hist_df['Date'] = pd.to_datetime(weights_hist_df['Date']).dt.strftime('%m-%Y')
weights_hist_df.head()
# Out:
#       Date      AAPL       ABT       AMD      AMZN      AVGO       AXP  \
# 0  03-2012  0.061585  0.011602  0.057022  0.001000  0.001000  0.001000
# 1  04-2012  0.064934  0.001000  0.062246  0.001000  0.065915  0.001000
# 2  05-2012  0.060354  0.001000  0.056814  0.001000  0.058504  0.081324
# 3  06-2012  0.057726  0.084618  0.001000  0.061781  0.001000  0.066398
# 4  07-2012  0.001000  0.080306  0.001000  0.063855  0.001000  0.063378
#
#         BAC     BRK-B       CAT  ...        PM      QCOM    RTX       TMO  \
# 0  0.055492  0.001000  0.061573  ...  0.001000  0.001000  0.001  0.037028
# 1  0.061963  0.013300  0.058687  ...  0.001000  0.001000  0.001  0.064505
# 2  0.056513  0.001831  0.001000  ...  0.070525  0.039153  0.001  0.001000
# 3  0.001000  0.001000  0.001000  ...  0.067551  0.001000  0.001  0.001000
# 4  0.001000  0.088129  0.001000  ...  0.001000  0.001000  0.001  0.001000
#
#        TMUS       UNH         V       WFC       WMT    XOM
# 0  0.058460  0.001000  0.001000  0.075279  0.001000  0.001
# 1  0.060071  0.001000  0.069006  0.001000  0.001000  0.001
# 2  0.001000  0.001000  0.066027  0.075218  0.001000  0.001
# 3  0.001000  0.071311  0.072108  0.063938  0.001000  0.001
# 4  0.001000  0.083829  0.066851  0.001000  0.066097  0.001
#
# [5 rows x 46 columns]

# %% [markdown]
# #### **GARCH WEIGHTS**

# %%
# Check ER structure
print("ER DATA:")
print(ER.head())
print(f"Shape: {ER.shape}")
print(f"Date range: {ER['Date'].min()} to {ER['Date'].max()}")
print(f"Columns: {ER.columns.tolist()}")

print("\n" + "="*50 + "\n")

# Check garch_vol structure
print("GARCH_VOL DATA:")
print(garch_vol.head())
print(f"Shape: {garch_vol.shape}")
print(f"Date range: {garch_vol['Date'].min()} to {garch_vol['Date'].max()}")
print(f"Columns: {garch_vol.columns.tolist()}")
# Out:
# ER DATA:
#         Date      AAPL       ABT       AMD      AMZN      AVGO       AXP  \
# 0 2012-01-03  0.000127  0.001078 -0.001161 -0.004720 -0.003342 -0.001480
# 1 2012-01-04  0.000980  0.001777  0.001357 -0.003747 -0.002725 -0.000097
# 2 2012-01-05  0.001054  0.001630  0.000551 -0.004344 -0.002848 -0.000729
# 3 2012-01-06  0.000979  0.001143 -0.000626 -0.004626 -0.004078 -0.001096
# 4 2012-01-09  0.001395  0.001153 -0.000508 -0.003758 -0.004263 -0.001124
#
#         BAC     BRK-B       CAT  ...        PM      QCOM       RTX       TMO  \
# 0 -0.004291 -0.000344 -0.000678  ...  0.003079  0.001708 -0.001222 -0.002482
# 1 -0.001765  0.000802  0.000924  ...  0.003491  0.002630  0.000141 -0.000674
# 2 -0.002914 -0.000088  0.000544  ...  0.003064  0.001902 -0.000279 -0.001715
# 3 -0.001538 -0.000457  0.000190  ...  0.002677  0.000207 -0.000981 -0.001752
# 4 -0.000582 -0.000147  0.000314  ...  0.002528  0.000084 -0.000925 -0.000435
#
#        TMUS       UNH         V       WFC       WMT       XOM
# 0  0.001296  0.001532  0.002230  0.001901  0.001446  0.002213
# 1  0.005597  0.002791  0.003397  0.003700  0.001878  0.003217
# 2  0.001247  0.003066  0.002583  0.003152  0.001367  0.002774
# 3 -0.002033  0.003318  0.002325  0.003084  0.001017  0.002244
# 4 -0.001950  0.003713  0.002183  0.003397  0.000815  0.002169
#
# [5 rows x 46 columns]
# Shape: (3455, 46)
# Date range: 2012-01-03 00:00:00 to 2025-09-29 00:00:00
# Columns: ['Date', 'AAPL', 'ABT', 'AMD', 'AMZN', 'AVGO', 'AXP', 'BAC', 'BRK-B', 'CAT', 'COST', 'CRM', 'CSCO', 'CVX', 'DIS', 'GE', 'GOOG', 'GOOGL', 'GS', 'HD', 'IBM', 'JNJ', 'JPM', 'KO', 'LLY', 'LRCX', 'MA', 'MCD', 'MRK', 'MS', 'MSFT', 'MU', 'NFLX', 'NVDA', 'ORCL', 'PG', 'PM', 'QCOM', 'RTX', 'TMO', 'TMUS', 'UNH', 'V', 'WFC', 'WMT', 'XOM']
#
# ==================================================
#
# GARCH_VOL DATA:
#         Date      AAPL       ABT       AMD      AMZN      AVGO       AXP  \
# 0 2012-01-03  0.013458  0.008226  0.032022  0.023880  0.024087  0.016478
# 1 2012-01-04  0.013765  0.008351  0.030897  0.024460  0.023295  0.017805
# 2 2012-01-05  0.013314  0.008144  0.029361  0.023915  0.023145  0.016886
# 3 2012-01-06  0.013222  0.007894  0.028299  0.023044  0.022390  0.016447
# 4 2012-01-09  0.013103  0.008211  0.027040  0.023306  0.021818  0.016257
#
#         BAC     BRK-B       CAT  ...        PM      QCOM       RTX       TMO  \
# 0  0.029601  0.011409  0.021006  ...  0.010866  0.017961  0.015487  0.017135
# 1  0.032086  0.013167  0.022836  ...  0.010512  0.017883  0.016076  0.020847
# 2  0.029648  0.013075  0.021814  ...  0.010214  0.017835  0.015319  0.020857
# 3  0.042460  0.011975  0.020805  ...  0.009959  0.019018  0.014969  0.019954
# 4  0.039742  0.011460  0.019831  ...  0.010570  0.017520  0.014404  0.020706
#
#        TMUS       UNH         V       WFC       WMT       XOM
# 0  0.030124  0.015558  0.019373  0.021250  0.007951  0.013128
# 1  0.038432  0.015848  0.018494  0.022284  0.008474  0.013195
# 2  0.035917  0.015920  0.019340  0.021287  0.009062  0.012493
# 3  0.055511  0.015616  0.017458  0.020857  0.008617  0.011915
# 4  0.040879  0.015193  0.017251  0.019985  0.008592  0.011642
#
# [5 rows x 46 columns]
# Shape: (3455, 46)
# Date range: 2012-01-03 00:00:00 to 2025-09-29 00:00:00
# Columns: ['Date', 'AAPL', 'ABT', 'AMD', 'AMZN', 'AVGO', 'AXP', 'BAC', 'BRK-B', 'CAT', 'COST', 'CRM', 'CSCO', 'CVX', 'DIS', 'GE', 'GOOG', 'GOOGL', 'GS', 'HD', 'IBM', 'JNJ', 'JPM', 'KO', 'LLY', 'LRCX', 'MA', 'MCD', 'MRK', 'MS', 'MSFT', 'MU', 'NFLX', 'NVDA', 'ORCL', 'PG', 'PM', 'QCOM', 'RTX', 'TMO', 'TMUS', 'UNH', 'V', 'WFC', 'WMT', 'XOM']

# %%
# Get date range
start_date = pd.to_datetime('2012-03-01')
end_date = ER['Date'].max()

# Storage for results
results_garch = []

current_start = start_date

while current_start <= end_date - relativedelta(months=2):
    # Define target month (the month we're optimizing for)
    target_month_start = current_start
    target_month_end = current_start + relativedelta(months=1)
    
    # Get returns for 2-month estimation period BEFORE target month
    estimation_start = current_start - relativedelta(months=2)
    returns_window = ER[(ER['Date'] >= estimation_start) & (ER['Date'] < current_start)].drop('Date', axis=1)
    
    # Skip if insufficient data
    if len(returns_window) < 20:
        current_start += relativedelta(months=1)
        continue
    
    # Calculate correlation matrix and expected returns from 2-month window
    R = returns_window.corr().values
    expected_returns = returns_window.mean().values
    
    # Get GARCH volatilities for target month (e.g., March 2012 GARCH for March 2012)
    garch_target_month = garch_vol[(garch_vol['Date'] >= target_month_start) & (garch_vol['Date'] < target_month_end)]
    
    if garch_target_month.empty:
        current_start += relativedelta(months=1)
        continue
    
    # Average GARCH volatilities across all days in target month
    vol_garch = garch_target_month.drop('Date', axis=1).mean().values
    
    # Build covariance matrix using GARCH volatilities
    D_garch = np.diag(vol_garch)
    Sigma_garch = D_garch @ R @ D_garch
    
    # Setup bounds and initial guess (using GARCH volatilities)
    bounds = volatility_based_bounds(vol_garch)
    init_guess = (1 / vol_garch) / (1 / vol_garch).sum()
    
    # Optimize portfolio
    weights_garch = mvo_optimize(expected_returns, Sigma_garch, bounds, init_guess)
    
    # Store results if optimization succeeded
    if weights_garch is not None:
        stock_names = returns_window.columns.tolist()
        
        # Store GARCH weights
        result_garch = {'Date': target_month_start}
        for name, weight in zip(stock_names, weights_garch):
            result_garch[name] = weight
        results_garch.append(result_garch)
        
        # Display info
        garch_days = len(garch_target_month)
        estimation_end = current_start - relativedelta(days=1)
        print(f"Estimation: {estimation_start.strftime('%Y-%m-%d')} to {estimation_end.strftime('%Y-%m-%d')} | GARCH vol: {garch_target_month['Date'].min().strftime('%Y-%m-%d')} to {garch_target_month['Date'].max().strftime('%Y-%m-%d')} ({garch_days} days) → Weights for {target_month_start.strftime('%Y-%m')}")
    
    # Move to next month
    current_start += relativedelta(months=1)

# Convert results to DataFrame
weights_garch_df = pd.DataFrame(results_garch)
# Out:
# Estimation: 2012-01-01 to 2012-02-29 | GARCH vol: 2012-03-01 to 2012-03-30 (22 days) → Weights for 2012-03
# Estimation: 2012-02-01 to 2012-03-31 | GARCH vol: 2012-04-02 to 2012-04-30 (20 days) → Weights for 2012-04
# Estimation: 2012-03-01 to 2012-04-30 | GARCH vol: 2012-05-01 to 2012-05-31 (22 days) → Weights for 2012-05
# Estimation: 2012-04-01 to 2012-05-31 | GARCH vol: 2012-06-01 to 2012-06-29 (21 days) → Weights for 2012-06
# Estimation: 2012-05-01 to 2012-06-30 | GARCH vol: 2012-07-02 to 2012-07-31 (21 days) → Weights for 2012-07
# Estimation: 2012-06-01 to 2012-07-31 | GARCH vol: 2012-08-01 to 2012-08-31 (23 days) → Weights for 2012-08
# Estimation: 2012-07-01 to 2012-08-31 | GARCH vol: 2012-09-04 to 2012-09-28 (19 days) → Weights for 2012-09
# Estimation: 2012-08-01 to 2012-09-30 | GARCH vol: 2012-10-01 to 2012-10-31 (21 days) → Weights for 2012-10
# Estimation: 2012-09-01 to 2012-10-31 | GARCH vol: 2012-11-01 to 2012-11-30 (21 days) → Weights for 2012-11
# Estimation: 2012-10-01 to 2012-11-30 | GARCH vol: 2012-12-03 to 2012-12-31 (20 days) → Weights for 2012-12
# Estimation: 2012-11-01 to 2012-12-31 | GARCH vol: 2013-01-02 to 2013-01-31 (21 days) → Weights for 2013-01
# Estimation: 2012-12-01 to 2013-01-31 | GARCH vol: 2013-02-01 to 2013-02-28 (19 days) → Weights for 2013-02
# Estimation: 2013-01-01 to 2013-02-28 | GARCH vol: 2013-03-01 to 2013-03-28 (20 days) → Weights for 2013-03
# Estimation: 2013-02-01 to 2013-03-31 | GARCH vol: 2013-04-01 to 2013-04-30 (22 days) → Weights for 2013-04
# Estimation: 2013-03-01 to 2013-04-30 | GARCH vol: 2013-05-01 to 2013-05-31 (22 days) → Weights for 2013-05
# Estimation: 2013-04-01 to 2013-05-31 | GARCH vol: 2013-06-03 to 2013-06-28 (20 days) → Weights for 2013-06
# Estimation: 2013-05-01 to 2013-06-30 | GARCH vol: 2013-07-01 to 2013-07-31 (22 days) → Weights for 2013-07
# Estimation: 2013-06-01 to 2013-07-31 | GARCH vol: 2013-08-01 to 2013-08-30 (22 days) → Weights for 2013-08
# Estimation: 2013-07-01 to 2013-08-31 | GARCH vol: 2013-09-03 to 2013-09-30 (20 days) → Weights for 2013-09
# Estimation: 2013-08-01 to 2013-09-30 | GARCH vol: 2013-10-01 to 2013-10-31 (23 days) → Weights for 2013-10
# Estimation: 2013-09-01 to 2013-10-31 | GARCH vol: 2013-11-01 to 2013-11-29 (20 days) → Weights for 2013-11
# Estimation: 2013-10-01 to 2013-11-30 | GARCH vol: 2013-12-02 to 2013-12-31 (21 days) → Weights for 2013-12
# Estimation: 2013-11-01 to 2013-12-31 | GARCH vol: 2014-01-02 to 2014-01-31 (21 days) → Weights for 2014-01
# Estimation: 2013-12-01 to 2014-01-31 | GARCH vol: 2014-02-03 to 2014-02-28 (19 days) → Weights for 2014-02
# Estimation: 2014-01-01 to 2014-02-28 | GARCH vol: 2014-03-03 to 2014-03-31 (21 days) → Weights for 2014-03
# Estimation: 2014-02-01 to 2014-03-31 | GARCH vol: 2014-04-01 to 2014-04-30 (21 days) → Weights for 2014-04
# Estimation: 2014-03-01 to 2014-04-30 | GARCH vol: 2014-05-01 to 2014-05-30 (21 days) → Weights for 2014-05
# Estimation: 2014-04-01 to 2014-05-31 | GARCH vol: 2014-06-02 to 2014-06-30 (21 days) → Weights for 2014-06
# Estimation: 2014-05-01 to 2014-06-30 | GARCH vol: 2014-07-01 to 2014-07-31 (22 days) → Weights for 2014-07
# Estimation: 2014-06-01 to 2014-07-31 | GARCH vol: 2014-08-01 to 2014-08-29 (21 days) → Weights for 2014-08
# Estimation: 2018-08-01 to 2018-09-30 | GARCH vol: 2018-10-01 to 2018-10-31 (23 days) → Weights for 2018-10
# Estimation: 2018-09-01 to 2018-10-31 | GARCH vol: 2018-11-01 to 2018-11-30 (21 days) → Weights for 2018-11
# Estimation: 2018-10-01 to 2018-11-30 | GARCH vol: 2018-12-03 to 2018-12-31 (19 days) → Weights for 2018-12
# Estimation: 2018-11-01 to 2018-12-31 | GARCH vol: 2019-01-02 to 2019-01-31 (21 days) → Weights for 2019-01
# Estimation: 2018-12-01 to 2019-01-31 | GARCH vol: 2019-02-01 to 2019-02-28 (19 days) → Weights for 2019-02
# Estimation: 2019-01-01 to 2019-02-28 | GARCH vol: 2019-03-01 to 2019-03-29 (21 days) → Weights for 2019-03
# Estimation: 2019-02-01 to 2019-03-31 | GARCH vol: 2019-04-01 to 2019-04-30 (21 days) → Weights for 2019-04
# Estimation: 2019-03-01 to 2019-04-30 | GARCH vol: 2019-05-01 to 2019-05-31 (22 days) → Weights for 2019-05
# Estimation: 2019-04-01 to 2019-05-31 | GARCH vol: 2019-06-03 to 2019-06-28 (20 days) → Weights for 2019-06
# Estimation: 2019-05-01 to 2019-06-30 | GARCH vol: 2019-07-01 to 2019-07-31 (22 days) → Weights for 2019-07
# Estimation: 2019-06-01 to 2019-07-31 | GARCH vol: 2019-08-01 to 2019-08-30 (22 days) → Weights for 2019-08
# Estimation: 2019-07-01 to 2019-08-31 | GARCH vol: 2019-09-03 to 2019-09-30 (20 days) → Weights for 2019-09
# Estimation: 2019-08-01 to 2019-09-30 | GARCH vol: 2019-10-01 to 2019-10-31 (23 days) → Weights for 2019-10
# Estimation: 2019-09-01 to 2019-10-31 | GARCH vol: 2019-11-01 to 2019-11-29 (20 days) → Weights for 2019-11
# Estimation: 2019-10-01 to 2019-11-30 | GARCH vol: 2019-12-02 to 2019-12-31 (21 days) → Weights for 2019-12
# Estimation: 2019-11-01 to 2019-12-31 | GARCH vol: 2020-01-02 to 2020-01-31 (21 days) → Weights for 2020-01
# Estimation: 2019-12-01 to 2020-01-31 | GARCH vol: 2020-02-03 to 2020-02-28 (19 days) → Weights for 2020-02
# Estimation: 2020-01-01 to 2020-02-29 | GARCH vol: 2020-03-02 to 2020-03-31 (22 days) → Weights for 2020-03
# Estimation: 2020-02-01 to 2020-03-31 | GARCH vol: 2020-04-01 to 2020-04-30 (21 days) → Weights for 2020-04
# Estimation: 2020-03-01 to 2020-04-30 | GARCH vol: 2020-05-01 to 2020-05-29 (20 days) → Weights for 2020-05
# Estimation: 2020-04-01 to 2020-05-31 | GARCH vol: 2020-06-01 to 2020-06-30 (22 days) → Weights for 2020-06
# Estimation: 2020-05-01 to 2020-06-30 | GARCH vol: 2020-07-01 to 2020-07-31 (22 days) → Weights for 2020-07
# Estimation: 2020-06-01 to 2020-07-31 | GARCH vol: 2020-08-03 to 2020-08-31 (21 days) → Weights for 2020-08
# Estimation: 2020-07-01 to 2020-08-31 | GARCH vol: 2020-09-01 to 2020-09-30 (21 days) → Weights for 2020-09
# Estimation: 2024-08-01 to 2024-09-30 | GARCH vol: 2024-10-01 to 2024-10-31 (23 days) → Weights for 2024-10
# Estimation: 2024-09-01 to 2024-10-31 | GARCH vol: 2024-11-01 to 2024-11-29 (20 days) → Weights for 2024-11
# Estimation: 2024-10-01 to 2024-11-30 | GARCH vol: 2024-12-02 to 2024-12-31 (21 days) → Weights for 2024-12
# Estimation: 2024-11-01 to 2024-12-31 | GARCH vol: 2025-01-02 to 2025-01-31 (20 days) → Weights for 2025-01
# Estimation: 2024-12-01 to 2025-01-31 | GARCH vol: 2025-02-03 to 2025-02-28 (19 days) → Weights for 2025-02
# Estimation: 2025-01-01 to 2025-02-28 | GARCH vol: 2025-03-03 to 2025-03-31 (21 days) → Weights for 2025-03
# Estimation: 2025-02-01 to 2025-03-31 | GARCH vol: 2025-04-01 to 2025-04-30 (21 days) → Weights for 2025-04
# Estimation: 2025-03-01 to 2025-04-30 | GARCH vol: 2025-05-01 to 2025-05-30 (21 days) → Weights for 2025-05
# Estimation: 2025-04-01 to 2025-05-31 | GARCH vol: 2025-06-02 to 2025-06-30 (20 days) → Weights for 2025-06
# Estimation: 2025-05-01 to 2025-06-30 | GARCH vol: 2025-07-01 to 2025-07-31 (22 days) → Weights for 2025-07

# %%
print(f"\nTotal portfolios created: {len(weights_garch_df)}")
print(f"Date range: {weights_garch_df['Date'].min()} to {weights_garch_df['Date'].max()}")
# Out:
# Total portfolios created: 161
# Date range: 2012-03-01 00:00:00 to 2025-07-01 00:00:00

# %%
weights_garch_df['Date'] = pd.to_datetime(weights_garch_df['Date']).dt.strftime('%m-%Y')
weights_garch_df.head()
# Out:
#       Date      AAPL       ABT       AMD      AMZN      AVGO       AXP  \
# 0  03-2012  0.069528  0.001000  0.061016  0.001000  0.001000  0.001000
# 1  04-2012  0.064821  0.001000  0.063043  0.001000  0.063011  0.001000
# 2  05-2012  0.065401  0.085246  0.062459  0.001000  0.001000  0.074398
# 3  06-2012  0.072384  0.089329  0.001000  0.064645  0.001000  0.069722
# 4  07-2012  0.001000  0.088330  0.001000  0.065246  0.001000  0.072182
#
#         BAC     BRK-B       CAT  ...        PM   QCOM    RTX       TMO  \
# 0  0.060361  0.001000  0.066676  ...  0.001000  0.001  0.001  0.001000
# 1  0.061383  0.001000  0.001000  ...  0.001000  0.001  0.001  0.070216
# 2  0.063950  0.001000  0.001000  ...  0.081494  0.001  0.001  0.001000
# 3  0.001000  0.001000  0.001000  ...  0.082504  0.001  0.001  0.001000
# 4  0.001000  0.085052  0.001000  ...  0.001000  0.001  0.001  0.001000
#
#        TMUS       UNH         V       WFC       WMT    XOM
# 0  0.001000  0.069757  0.001000  0.065522  0.001000  0.001
# 1  0.063918  0.001000  0.067313  0.001000  0.001000  0.001
# 2  0.001000  0.066429  0.067196  0.069474  0.001000  0.001
# 3  0.001000  0.072088  0.001000  0.001000  0.073667  0.001
# 4  0.001000  0.069135  0.010179  0.001000  0.084903  0.001
#
# [5 rows x 46 columns]

# %%
weights_hist_df.to_excel("all_data/weights_hist.xlsx", index=False)
weights_garch_df.to_excel("all_data/weights_garch.xlsx", index=False)
